# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/raw_house_data.csv')
df
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 0     21530491   5300000.0    85637 -110.378200  31.356362    2154.00
# 1     21529082   4200000.0    85646 -111.045371  31.594213    1707.00
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 4     21306357   3411450.0    85750 -110.813768  32.285162       3.21
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms bathrooms sqrt_ft garage  \
# 0      5272.00        1941        13        10   10500      0
# ...

# %% [markdown]
# ## Understanding the Data

# %%
df.shape
# Out:
# (5000, 16)

# %%
df.head(7)
# Out:
#         MLS  sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0  21530491   5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1  21529082   4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2   3054672   4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3  21919321   4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4  21306357   3411450.0    85750 -110.813768  32.285162       3.21  15393.00
# 5  21528016   3250000.0    85718 -110.910593  32.339090       1.67  27802.84
# 6  21610478   2400000.0    85712 -110.883315  32.261069       2.10  19038.42
#
#    year_built  bedrooms bathrooms sqrt_ft garage  \
# 0        1941        13        10   10500      0
# 1        1997         2         2    7300      0
# 2        1997         2         3    None   None
# 3        1930         7         5    9019      4
# 4        1995         4         6    6396      3
# 5        1999         3         4    6842      3
# ...

# %%
df.tail(3)
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#         taxes  year_built  bedrooms bathrooms sqrt_ft garage  \
# 4997  1000.00        1969         3         2    1772      0
# 4998  5822.93        2009         4         4    3724      3
# 4999  2814.48        1988         4         4    4317   None
#
#                                        kitchen_features fireplaces  \
# 4997  Dishwasher, Electric Range, Island, Refrigerat...          0
# 4998  Dishwasher, Double Sink, Garbage Disposal, Gas...          1
# 4999  Compactor, Dishwasher, Double Sink, Island, Ap...          3
#
#             floor_covering   HOA
# 4997          Ceramic Tile  None
# 4998  Carpet, Ceramic Tile  None
# 4999  Carpet, Mexican Tile  None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MLS               5000 non-null   int64
#  1   sold_price        5000 non-null   float64
#  2   zipcode           5000 non-null   int64
#  3   longitude         5000 non-null   float64
#  4   latitude          5000 non-null   float64
#  5   lot_acres         4990 non-null   float64
#  6   taxes             5000 non-null   float64
#  7   year_built        5000 non-null   int64
#  8   bedrooms          5000 non-null   int64
#  9   bathrooms         5000 non-null   object
#  10  sqrt_ft           5000 non-null   object
#  11  garage            5000 non-null   object
#  12  kitchen_features  5000 non-null   object
#  13  fireplaces        5000 non-null   object
#  14  floor_covering    5000 non-null   object
#  15  HOA               5000 non-null   object
# ...

# %%
df['bathrooms'].unique()
# Out:
# array(['10', '2', '3', '5', '6', '4', '8', '7', '15', '4.5', '1', '9',
#        '11', '18', '14', '3.5', 'None', '35', '2.5', '36'], dtype=object)

# %%
# outliers will affect the model performance. Ml algorithms job is to generalise for the population, but outliers will skew the results
#always remove oultliers

# %%
df['bathrooms'].nunique()
# Out:
# 20

# %%
#describe

df.describe()
# Out:
#                 MLS    sold_price       zipcode    longitude     latitude  \
# count  5.000000e+03  5.000000e+03   5000.000000  5000.000000  5000.000000
# mean   2.127070e+07  7.746262e+05  85723.025600  -110.912107    32.308512
# std    2.398508e+06  3.185556e+05     38.061712     0.120629     0.178028
# min    3.042851e+06  1.690000e+05  85118.000000  -112.520168    31.356362
# 25%    2.140718e+07  5.850000e+05  85718.000000  -110.979260    32.277484
# 50%    2.161469e+07  6.750000e+05  85737.000000  -110.923420    32.318517
# 75%    2.180480e+07  8.350000e+05  85749.000000  -110.859078    32.394334
# max    2.192856e+07  5.300000e+06  86323.000000  -109.454637    34.927884
#
#          lot_acres         taxes  year_built     bedrooms
# count  4990.000000  5.000000e+03  5000.00000  5000.000000
# mean      4.661317  9.402828e+03  1992.32800     3.933800
# std      51.685230  1.729385e+05    65.48614     1.245362
# min       0.000000  0.000000e+00     0.00000     1.000000
# ...

# %%
df.describe().T #Transpose
# Out:
#              count          mean           std           min           25%  \
# MLS         5000.0  2.127070e+07  2.398508e+06  3.042851e+06  2.140718e+07
# sold_price  5000.0  7.746262e+05  3.185556e+05  1.690000e+05  5.850000e+05
# zipcode     5000.0  8.572303e+04  3.806171e+01  8.511800e+04  8.571800e+04
# longitude   5000.0 -1.109121e+02  1.206294e-01 -1.125202e+02 -1.109793e+02
# latitude    5000.0  3.230851e+01  1.780284e-01  3.135636e+01  3.227748e+01
# lot_acres   4990.0  4.661317e+00  5.168523e+01  0.000000e+00  5.800000e-01
# taxes       5000.0  9.402828e+03  1.729385e+05  0.000000e+00  4.803605e+03
# year_built  5000.0  1.992328e+03  6.548614e+01  0.000000e+00  1.987000e+03
# bedrooms    5000.0  3.933800e+00  1.245362e+00  1.000000e+00  3.000000e+00
#
#                      50%           75%           max
# MLS         2.161469e+07  2.180480e+07  2.192856e+07
# sold_price  6.750000e+05  8.350000e+05  5.300000e+06
# zipcode     8.573700e+04  8.574900e+04  8.632300e+04
# ...

# %%
df['sold_price'].describe()
# Out:
# count    5.000000e+03
# mean     7.746262e+05
# std      3.185556e+05
# min      1.690000e+05
# 25%      5.850000e+05
# 50%      6.750000e+05
# 75%      8.350000e+05
# max      5.300000e+06
# Name: sold_price, dtype: float64

# %% [markdown]
# ## Data Cleaning

# %%
#Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Our new dataframe

df2 = pd.DataFrame({
    'Movie' : ['Avatar', 'Avatar', 'Star Wars', 'Incredibles', 'Spider-Man', 'Star Wars'],
    'Genre' : ['Action', 'Action', 'Sci-Fi', 'Cartoon', 'Comic', 'Sci-Fi'],
    'IMDB_Rating' : [8.8, 8.8, 8.3, 7.5, 9.2, 8.3]
})

# %%
df2
# Out:
#          Movie    Genre  IMDB_Rating
# 0       Avatar   Action          8.8
# 1       Avatar   Action          8.8
# 2    Star Wars   Sci-Fi          8.3
# 3  Incredibles  Cartoon          7.5
# 4   Spider-Man    Comic          9.2
# 5    Star Wars   Sci-Fi          8.3

# %%
df2.duplicated().sum()
# Out:
# 2

# %%
#df2 = df2.drop_duplicates()

# %%
df2
# Out:
#          Movie    Genre  IMDB_Rating
# 0       Avatar   Action          8.8
# 2    Star Wars   Sci-Fi          8.3
# 3  Incredibles  Cartoon          7.5
# 4   Spider-Man    Comic          9.2

# %%
df2.drop_duplicates(inplace = True)
df2
# Out:
#          Movie    Genre  IMDB_Rating
# 0       Avatar   Action          8.8
# 2    Star Wars   Sci-Fi          8.3
# 3  Incredibles  Cartoon          7.5
# 4   Spider-Man    Comic          9.2

# %%
#missing values

df.isna().sum()
# Out:
# MLS                  0
# sold_price           0
# zipcode              0
# longitude            0
# latitude             0
# lot_acres           10
# taxes                0
# year_built           0
# bedrooms             0
# bathrooms            0
# sqrt_ft              0
# garage               0
# kitchen_features     0
# fireplaces           0
# floor_covering       0
# HOA                  0
# dtype: int64

# %%
df.dropna(inplace = True)
df.shape
# Out:
# (4990, 16)

# %%
df2 = pd.DataFrame({
    'Movie' : ['Avatar', 'Avatar', 'Star Wars', 'Incredibles', 'Spider-Man', 'Star Wars'],
    'Genre' : ['Action', 'Action', 'Sci-Fi', 'Cartoon', 'Comic', 'Sci-Fi'],
    'IMDB_Rating' : [None, 8.8, 8.3, 7.5, 9.2, 8.3]
})

# %%
df2.isna().sum()
# Out:
# Movie          0
# Genre          0
# IMDB_Rating    1
# dtype: int64

# %%
#df2.dropna(inplace = True)
df2

# %%
df2 = pd.DataFrame({
    'Movie' : ['Avatar', 'Avatar', 'Star Wars', 'Incredibles', 'Spider-Man', 'Star Wars'],
    'Genre' : ['Action', 'Action', 'Sci-Fi', 'Cartoon', 'Comic', 'Sci-Fi'],
    'IMDB_Rating' : [None, 8.8, 8.3, 7.5, 9.2, 8.3]
})

# %%
df2.fillna(9.7)
# Out:
#          Movie    Genre  IMDB_Rating
# 0       Avatar   Action          9.7
# 1       Avatar   Action          8.8
# 2    Star Wars   Sci-Fi          8.3
# 3  Incredibles  Cartoon          7.5
# 4   Spider-Man    Comic          9.2
# 5    Star Wars   Sci-Fi          8.3

# %% [markdown]
# ## Feature Engineering

# %%
df.head()
# Out:
#         MLS  sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0  21530491   5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1  21529082   4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2   3054672   4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3  21919321   4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4  21306357   3411450.0    85750 -110.813768  32.285162       3.21  15393.00
#
#    year_built  bedrooms bathrooms sqrt_ft garage  \
# 0        1941        13        10   10500      0
# 1        1997         2         2    7300      0
# 2        1997         2         3    None   None
# 3        1930         7         5    9019      4
# 4        1995         4         6    6396      3
#
#                                     kitchen_features fireplaces  \
# 0            Dishwasher, Freezer, Refrigerator, Oven          6
# 1                       Dishwasher, Garbage Disposal          5
# ...

# %%
# iloc and loc
#df.iloc[3]
df.iloc[[0,1,4]]
# Out:
#         MLS  sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0  21530491   5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1  21529082   4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 4  21306357   3411450.0    85750 -110.813768  32.285162       3.21  15393.00
#
#    year_built  bedrooms bathrooms sqrt_ft garage  \
# 0        1941        13        10   10500      0
# 1        1997         2         2    7300      0
# 4        1995         4         6    6396      3
#
#                                     kitchen_features fireplaces  \
# 0            Dishwasher, Freezer, Refrigerator, Oven          6
# 1                       Dishwasher, Garbage Disposal          5
# 4  Dishwasher, Garbage Disposal, Refrigerator, Mi...          5
#
#          floor_covering HOA
# 0    Mexican Tile, Wood   0
# 1  Natural Stone, Other   0
# 4      Carpet, Concrete  55

# %%
df.columns
# Out:
# Index(['MLS', 'sold_price', 'zipcode', 'longitude', 'latitude', 'lot_acres',
#        'taxes', 'year_built', 'bedrooms', 'bathrooms', 'sqrt_ft', 'garage',
#        'kitchen_features', 'fireplaces', 'floor_covering', 'HOA'],
#       dtype='object')

# %%
df_subset = df[['MLS', 'sold_price',
       'taxes', 'year_built', 'bedrooms', 'bathrooms']]
df_subset
# Out:
#            MLS  sold_price     taxes  year_built  bedrooms bathrooms
# 0     21530491   5300000.0   5272.00        1941        13        10
# 1     21529082   4200000.0  10422.36        1997         2         2
# 2      3054672   4200000.0  10482.00        1997         2         3
# 3     21919321   4500000.0   8418.58        1930         7         5
# 4     21306357   3411450.0  15393.00        1995         4         6
# ...        ...         ...       ...         ...       ...       ...
# 4995  21810382    495000.0   2017.00        2005         5         3
# 4996  21908591    550000.0   4822.01        1990         4         3
# 4997  21832452    475000.0   1000.00        1969         3         2
# 4998  21900515    550000.0   5822.93        2009         4         4
# 4999   4111490    450000.0   2814.48        1988         4         4
#
# [4990 rows x 6 columns]

# %%
df.head()
# Out:
#         MLS  sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0  21530491   5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1  21529082   4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2   3054672   4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3  21919321   4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4  21306357   3411450.0    85750 -110.813768  32.285162       3.21  15393.00
#
#    year_built  bedrooms bathrooms sqrt_ft garage  \
# 0        1941        13        10   10500      0
# 1        1997         2         2    7300      0
# 2        1997         2         3    None   None
# 3        1930         7         5    9019      4
# 4        1995         4         6    6396      3
#
#                                     kitchen_features fireplaces  \
# 0            Dishwasher, Freezer, Refrigerator, Oven          6
# 1                       Dishwasher, Garbage Disposal          5
# ...

# %%
df.drop('MLS', axis = 1, inplace = True)  # rows = axis 0 and columns = axis 1

# %%
df
# Out:
#       sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0      5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1      4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2      4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3      4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4      3411450.0    85750 -110.813768  32.285162       3.21  15393.00
# ...          ...      ...         ...        ...        ...       ...
# 4995    495000.0    85641 -110.661829  31.907917       4.98   2017.00
# 4996    550000.0    85750 -110.858556  32.316373       1.42   4822.01
# 4997    475000.0    85192 -110.755428  32.964708      12.06   1000.00
# 4998    550000.0    85745 -111.055528  32.296871       1.01   5822.93
# 4999    450000.0    85621 -110.913054  31.385259       4.16   2814.48
#
#       year_built  bedrooms bathrooms sqrt_ft garage  \
# 0           1941        13        10   10500      0
# ...

# %%
df['greetings'] = 'hello'
df
# Out:
#       sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0      5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1      4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2      4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3      4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4      3411450.0    85750 -110.813768  32.285162       3.21  15393.00
# ...          ...      ...         ...        ...        ...       ...
# 4995    495000.0    85641 -110.661829  31.907917       4.98   2017.00
# 4996    550000.0    85750 -110.858556  32.316373       1.42   4822.01
# 4997    475000.0    85192 -110.755428  32.964708      12.06   1000.00
# 4998    550000.0    85745 -111.055528  32.296871       1.01   5822.93
# 4999    450000.0    85621 -110.913054  31.385259       4.16   2814.48
#
#       year_built  bedrooms bathrooms sqrt_ft garage  \
# 0           1941        13        10   10500      0
# ...

# %%
# new column = price per square foot ppsf

# %%
df['age'] = 2023 - df['year_built']
df
# Out:
#       sold_price  zipcode   longitude   latitude  lot_acres     taxes  \
# 0      5300000.0    85637 -110.378200  31.356362    2154.00   5272.00
# 1      4200000.0    85646 -111.045371  31.594213    1707.00  10422.36
# 2      4200000.0    85646 -111.040707  31.594844    1707.00  10482.00
# 3      4500000.0    85646 -111.035925  31.645878     636.67   8418.58
# 4      3411450.0    85750 -110.813768  32.285162       3.21  15393.00
# ...          ...      ...         ...        ...        ...       ...
# 4995    495000.0    85641 -110.661829  31.907917       4.98   2017.00
# 4996    550000.0    85750 -110.858556  32.316373       1.42   4822.01
# 4997    475000.0    85192 -110.755428  32.964708      12.06   1000.00
# 4998    550000.0    85745 -111.055528  32.296871       1.01   5822.93
# 4999    450000.0    85621 -110.913054  31.385259       4.16   2814.48
#
#       year_built  bedrooms bathrooms sqrt_ft garage  \
# 0           1941        13        10   10500      0
# ...

# %%
sns.boxplot(x = df['sold_price'])
# Out:
# <Axes: xlabel='sold_price'>

# %%
corr = df.corr()
plt.figure(figsize = (12,8))
sns.heatmap(corr, annot = True)

#Multicolinearity - # refers to a situation which two or more independent variables in a ml model are highly corelated.
# Out:
# <ipython-input-64-29b435fe99ed>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
# <Axes: >
